# %%
from imutils import *

# %%
image = imread('test.jpg')
show(image)

# %%
image = imread('test.jpg')
image = image[0:200,50:200]
show(image)

# %%
image = imread('test.jpg')
image = image[200:,50:-50]
show(image)
